# %%
import pandas as pd

# %%
df = pd.read_csv('../data/railwayFeedback.csv')

# %%
df.columns = ['complaint']

# %%
df.head(100)
# Out:
#                                             complaint
# 0   Rly station gets bag scanner, still lacks adeq...
# 1   The sensitivity of  towards the  corridor betw...
# 2   If you have  Loyalty points then you can easil...
# 3   Dear sir, I am travelling to ghazipur by 22434...
# 4   The sensitivity of  towards the  corridor betw...
# 5   Use Check Chart/ Vacancy section to check all ...
# 6   Condition of train no. 12322, all coaches extr...
# 7            cant be trusted in emergency situation.
# 8   Trains between Agra cantt(agc) And Jhansi(jhs)...
# 9   Indian railways IRCTC website is the LEAST rel...
# 10  The sensitivity of  towards the  corridor betw...
# 11  Condition of train no. 12322, all coaches extr...
# 12  see the condition and cleanliness of train no....
# 13  Flashback to the iconic first ever fashion sho...
# 14  Use Check Chart/ Vacancy section to check all ...
# 15  The sensitivity of  towards the  corridor betw...
# ...

# %%
f = df.iloc[21]

# %%
f
# Out:
# complaint    1/5  on  by sivasss1992 : Raptisagar-express-1...
# Name: 21, dtype: object

# %%
from textblob import TextBlob

# %%
TextBlob(df.iloc[99][0]).sentiment.polarity
# Out:
# 0.0
